# %% [markdown]
# # Pregunta 1
# ### Carrega el conjunt de dades en un DataFrame

# %%
import pandas as pd
import matplotlib.pyplot as plt

dades_vendes=pd.read_csv("./data/trainVendes.csv")
# Out:
# C:\Users\Josep\AppData\Local\Temp\ipykernel_6736\4148558247.py:4: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dades_vendes=pd.read_csv("./data/trainVendes.csv")

# %% [markdown]
# # Pregunta 2
# ### Mostra informació bàsica del conjunt de dades (nombre de files, columnes, tipus de dades, etc.).

# %%
dades_vendes.info()

# També el pot gastar describe
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 9 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   Store          1017209 non-null  int64
#  1   DayOfWeek      1017209 non-null  int64
#  2   Date           1017209 non-null  object
#  3   Sales          1017209 non-null  int64
#  4   Customers      1017209 non-null  int64
#  5   Open           1017209 non-null  int64
#  6   Promo          1017209 non-null  int64
#  7   StateHoliday   1017209 non-null  object
#  8   SchoolHoliday  1017209 non-null  int64
# dtypes: int64(7), object(2)
# memory usage: 69.8+ MB

# %% [markdown]
# # Pregunta 3
# ### Calcula i mostra les estadístiques descriptives de la columna "Sales".

# %%
# Calcular i mostrar estadístiques descriptives de la columna "Sales"
if "Sales" in dades_vendes.columns:
    print("Estadístiques descriptives de la columna 'Sales':")
    print(dades_vendes["Sales"].describe())
else:
    print("La columna 'Sales' no es troba al dataset.")
# Out:
# Estadístiques descriptives de la columna 'Sales':
# count    1.017209e+06
# mean     5.773819e+03
# std      3.849926e+03
# min      0.000000e+00
# 25%      3.727000e+03
# 50%      5.744000e+03
# 75%      7.856000e+03
# max      4.155100e+04
# Name: Sales, dtype: float64

# %% [markdown]
# # Pregunta 4
# ### Troba la botiga amb les vendes totals més altes.

# %%
botiga_max_vendes = dades_vendes.groupby("Store")["Sales"].sum().idxmax()
vendes_maximes = dades_vendes.groupby("Store")["Sales"].sum().max()
print(f"La botiga amb les vendes totals més altes és: {botiga_max_vendes} amb {vendes_maximes} unitats venudes.")
# Out:
# La botiga amb les vendes totals més altes és: 262 amb 19516842 unitats venudes.

# %% [markdown]
# # Pregunta 5
# ### Visualitza la tendència de les vendes al llarg del temps (pots utilitzar un gràfic de línia).

# %%
dades_vendes["Date"] = pd.to_datetime(dades_vendes["Date"])  
vendes_temps = dades_vendes.groupby("Date")["Sales"].sum()
plt.figure(figsize=(10, 6))
plt.plot(vendes_temps.index, vendes_temps.values, marker="o", linestyle="-", color="b")
plt.title("Tendència de les Vendes al Llarg del Temps")
plt.xlabel("Data")
plt.ylabel("Vendes Totals")
plt.grid(True)
plt.show()

# %% [markdown]
# # Pregunta 6
# ### Calcula la mitjana de vendes quan la botiga està oberta i hi ha una promoció.

# %% [markdown]
# # Pregunta 7
# ### Crea un nou DataFrame que contingui només les files on les vendes són superiors a 0 i la botiga va estar oberta.

# %% [markdown]
# # Pregunta 8
# ### Recorda documentar el teu codi i proporcionar explicacions clares per a cada pas. Bona sort!
